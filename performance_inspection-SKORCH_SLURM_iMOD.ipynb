# %% [markdown]
# # skorch slurm run from Sept 15 ish, Multi-task all iMods

# %%
import pandas as pd
import numpy as np
import utils as u
import matplotlib.pyplot as plt
import matplotlib

import altair as alt
import torch_utils as tu

# %% [markdown]
# ## Looking at skorch slurm results

# %%
res_df = pd.read_csv('../hyak_scp_dump/hp_search_ecoli_imods_all/hp_search_ecoli_imods_all_skres_df.tsv',sep='\t')
res_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     182.989505      0.047490         0.023401        0.002306
# 1     164.632153     26.324184         0.028346        0.007118
# 2     107.426788      0.017764         0.017856        0.000119
# 3     105.868227      1.293131         0.018336        0.001197
# 4     106.246087      1.008322         0.021048        0.002823
#
#                          param_optimizer  param_module__num_filters2  \
# 0          <class 'torch.optim.sgd.SGD'>                          64
# 1      <class 'torch.optim.adamw.AdamW'>                          64
# 2  <class 'torch.optim.rmsprop.RMSprop'>                         128
# 3  <class 'torch.optim.rmsprop.RMSprop'>                          32
# 4      <class 'torch.optim.adamw.AdamW'>                         128
#
#    param_module__num_filters1  param_module__kernel_size2  \
# 0                         128                           8
# 1                         256                          24
# 2                          32                          12
# 3                         128                          12
# 4                          32                          16
#
#    param_module__kernel_size1  param_module__fc_node_num2  ...  \
# 0                          12                         100  ...
# 1                          16                          50  ...
# 2                          16                          50  ...
# 3                          12                         100  ...
# 4                          24                          25  ...
#
#    param_module__conv_pool_size1  param_lr  \
# 0                              1    0.0010
# 1                              3    0.0005
# 2                              3    0.0005
# 3                              3    0.0001
# 4                              3    0.0005
#
#                                               params  split0_test_f1_macro  \
# 0  {'optimizer': <class 'torch.optim.sgd.SGD'>, '...              0.005371
# 1  {'optimizer': <class 'torch.optim.adamw.AdamW'...              0.006013
# 2  {'optimizer': <class 'torch.optim.rmsprop.RMSp...              0.000000
# 3  {'optimizer': <class 'torch.optim.rmsprop.RMSp...              0.001815
# 4  {'optimizer': <class 'torch.optim.adamw.AdamW'...              0.000000
#
#    split1_test_f1_macro split2_test_f1_macro  mean_test_f1_macro  \
# 0              0.006521             0.000981            0.004291
# 1              0.008250             0.001014            0.005092
# 2              0.001232             0.000000            0.000411
# 3              0.001277             0.000000            0.001031
# 4              0.000000             0.000000            0.000000
#
#    std_test_f1_macro  rank_test_f1_macro  opt_name
# 0           0.002387                 175       SGD
# 1           0.003025                 128     AdamW
# 2           0.000581                 423   RMSprop
# 3           0.000761                 387   RMSprop
# 4           0.000000                 432     AdamW
#
# [5 rows x 23 columns]

# %%
res_df.sort_values('rank_test_f1_macro')
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 338     201.376460     54.808478         0.016605        0.005544
# 270     127.427021     14.987583         0.019822        0.001482
# 106      91.524347      0.306793         0.017482        0.001099
# 113     117.322051      5.564195         0.021695        0.000501
# 33      155.423862      6.522214         0.025071        0.003102
# ..             ...           ...              ...             ...
# 107      94.696853      0.383891         0.018565        0.002265
# 245     180.213323      1.225411         0.025378        0.003238
# 140     146.354351      0.120673         0.018550        0.000823
# 150     338.051480     12.769510         0.043633        0.001712
# 457     164.596177      6.098540         0.018606        0.001330
#
#                            param_optimizer  param_module__num_filters2  \
# 338      <class 'torch.optim.adamw.AdamW'>                         128
# 270          <class 'torch.optim.sgd.SGD'>                          32
# 106          <class 'torch.optim.sgd.SGD'>                          32
# 113      <class 'torch.optim.adamw.AdamW'>                          32
# 33       <class 'torch.optim.adamw.AdamW'>                         128
# ..                                     ...                         ...
# 107      <class 'torch.optim.adamw.AdamW'>                          32
# 245  <class 'torch.optim.rmsprop.RMSprop'>                          64
# 140      <class 'torch.optim.adamw.AdamW'>                         128
# 150  <class 'torch.optim.rmsprop.RMSprop'>                         128
# 457      <class 'torch.optim.adamw.AdamW'>                          64
#
#      param_module__num_filters1  param_module__kernel_size2  \
# 338                         128                          12
# 270                         128                          12
# 106                          64                          12
# 113                          32                          12
# 33                           64                           8
# ..                          ...                         ...
# 107                          32                          24
# 245                         256                           8
# 140                          64                           8
# 150                         256                          12
# 457                          32                          12
#
#      param_module__kernel_size1  param_module__fc_node_num2  ...  \
# 338                          16                          50  ...
# 270                          24                         250  ...
# 106                          12                          50  ...
# 113                          24                         250  ...
# 33                           12                         250  ...
# ..                          ...                         ...  ...
# 107                          16                          50  ...
# 245                          16                          25  ...
# 140                          12                          25  ...
# 150                          16                          25  ...
# 457                           8                         250  ...
#
#      param_module__conv_pool_size1  param_lr  \
# 338                              3    0.0010
# 270                              3    0.0001
# 106                              3    0.0005
# 113                              3    0.0005
# 33                               3    0.0005
# ..                             ...       ...
# 107                              1    0.0010
# 245                              1    0.0010
# 140                              1    0.0005
# 150                              1    0.0010
# 457                              1    0.0005
#
#                                                 params  split0_test_f1_macro  \
# 338  {'optimizer': <class 'torch.optim.adamw.AdamW'...              0.012823
# 270  {'optimizer': <class 'torch.optim.sgd.SGD'>, '...              0.005555
# 106  {'optimizer': <class 'torch.optim.sgd.SGD'>, '...              0.003400
# 113  {'optimizer': <class 'torch.optim.adamw.AdamW'...              0.000000
# 33   {'optimizer': <class 'torch.optim.adamw.AdamW'...              0.010086
# ..                                                 ...                   ...
# 107  {'optimizer': <class 'torch.optim.adamw.AdamW'...              0.000000
# 245  {'optimizer': <class 'torch.optim.rmsprop.RMSp...              0.000000
# 140  {'optimizer': <class 'torch.optim.adamw.AdamW'...              0.000000
# 150  {'optimizer': <class 'torch.optim.rmsprop.RMSp...              0.000000
# 457  {'optimizer': <class 'torch.optim.adamw.AdamW'...              0.000000
#
#      split1_test_f1_macro split2_test_f1_macro  mean_test_f1_macro  \
# 338              0.017197             0.010240            0.013420
# 270              0.015510             0.010843            0.010636
# 106              0.018537             0.009790            0.010576
# 113              0.012356             0.019157            0.010504
# 33               0.013072             0.007940            0.010366
# ..                    ...                  ...                 ...
# 107              0.000000             0.000000            0.000000
# 245              0.000000             0.000000            0.000000
# 140              0.000000             0.000000            0.000000
# 150              0.000000             0.000000            0.000000
# 457              0.000000             0.000000            0.000000
#
#      std_test_f1_macro  rank_test_f1_macro  opt_name
# 338           0.002871                   1     AdamW
# 270           0.004067                   2       SGD
# 106           0.006204                   3       SGD
# 113           0.007930                   4     AdamW
# 33            0.002105                   5     AdamW
# ..                 ...                 ...       ...
# 107           0.000000                 432     AdamW
# 245           0.000000                 432   RMSprop
# 140           0.000000                 432     AdamW
# 150           0.000000                 432   RMSprop
# 457           0.000000                 432     AdamW
#
# [500 rows x 23 columns]

# %%
res_df.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_optimizer', 'param_module__num_filters2',
#        'param_module__num_filters1', 'param_module__kernel_size2',
#        'param_module__kernel_size1', 'param_module__fc_node_num2',
#        'param_module__fc_node_num1', 'param_module__dropout2',
#        'param_module__dropout1', 'param_module__conv_pool_size1', 'param_lr',
#        'params', 'split0_test_f1_macro', 'split1_test_f1_macro',
#        'split2_test_f1_macro', 'mean_test_f1_macro', 'std_test_f1_macro',
#        'rank_test_f1_macro', 'opt_name'],
#       dtype='object')

# %%
sm_res_df = res_df[
    ["rank_test_f1_macro",
     "mean_test_f1_macro",
     "param_module__num_filters2",
     "param_module__num_filters1",
     "param_module__kernel_size2",
     "param_module__kernel_size1",
     "param_lr",
     "param_module__fc_node_num2",
     "param_module__fc_node_num1",
     "param_module__conv_pool_size1",
     "param_module__dropout1",
     "param_module__dropout2",
     "opt_name"]]

# %%
alt.Chart(sm_res_df).mark_point(size=100).encode(
    x='rank_test_f1_macro:Q',
    y='mean_test_f1_macro:Q',
    #color=alt.Color('param_lr:Q',scale=alt.Scale(type='log',scheme='viridis')),
    color=alt.Color('param_lr:N',scale=alt.Scale(scheme='tableau10')),
    shape="opt_name:N",
    tooltip=["rank_test_f1_macro:Q","mean_test_f1_macro:Q","param_module__num_filters2:N","param_module__num_filters1:N","param_module__kernel_size2:N","param_module__kernel_size1:N","param_lr:N","param_module__fc_node_num1:N","opt_name:N"]
    
).interactive()
# Out:
# alt.Chart(...)

# %%
alt.Chart(sm_res_df).mark_point(size=100).encode(
    x=alt.X('param_module__kernel_size1:O',title="kernel size 1"),
    y='mean_test_f1_macro:Q',
    color=alt.Color('param_lr:N',scale=alt.Scale(scheme='tableau10')),
    column='opt_name:N',
#     detail='model_desc:N',
    shape="param_module__num_filters1:N",
    tooltip=["rank_test_f1_macro:O","param_module__num_filters1:N","param_module__num_filters2:N","param_module__kernel_size1:N","param_module__kernel_size2:N","param_lr:N","param_module__fc_node_num1:N"]
    
).interactive()
# Out:
# alt.Chart(...)

# %%
alt.Chart(sm_res_df).mark_point(size=100).encode(
    x=alt.X('param_module__kernel_size1:O',title="kernel size 1"),
    y='mean_test_f1_macro:Q',
    color=alt.Color('param_lr:N',scale=alt.Scale(scheme='tableau10')),
    column='param_module__num_filters1:N',
#     detail='model_desc:N',
    shape="opt_name:N",
    tooltip=["rank_test_score:O","param_module__num_filters1:N","param_module__kernel_size1:N","param_lr:N","param_module__fc_node_num1:N"]
    
).interactive()
# Out:
# alt.Chart(...)

# %%
alt.Chart(sm_res_df).mark_point(size=100).encode(
    x=alt.X('param_module__num_filters2:O'),#title="kernel size 1"),
    y='mean_test_f1_macro:Q',
    color=alt.Color('param_lr:N',scale=alt.Scale(scheme='tableau10')),
    column='param_module__num_filters1:N',
#     detail='model_desc:N',
    shape="opt_name:N",
    tooltip=["rank_test_score:O","param_module__num_filters1:N","param_module__kernel_size1:N","param_lr:N","param_module__fc_node_num1:N"]
    
).interactive()
# Out:
# alt.Chart(...)

# %%
alt.Chart(sm_res_df).mark_boxplot(extent='min-max').encode(
    x=alt.X('param_module__num_filters1:O'),#title="kernel size 1"),
    y='mean_test_f1_macro:Q',
    #color=alt.Color('param_lr:N',scale=alt.Scale(scheme='tableau10')),
    column='opt_name:N',
    row='param_lr:N',
).interactive(
).properties(
    height=100,
    width=100
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(sm_res_df).mark_boxplot(extent='min-max').encode(
    x=alt.X('param_module__kernel_size1:O'),#title="kernel size 1"),
    y='mean_test_f1_macro:Q',
    #color=alt.Color('param_lr:N',scale=alt.Scale(scheme='tableau10')),
    column='opt_name:N',
    row='param_lr:N',   
).interactive(
).properties(
    height=100,
    width=100
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(sm_res_df).mark_boxplot(extent='min-max').encode(
    x=alt.X('param_module__dropout1:O'),#title="kernel size 1"),
    y='mean_test_f1_macro:Q',
    column='opt_name:N',
    row='param_lr:N', 
).interactive(
).properties(
    height=100,
    width=100
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(sm_res_df).mark_boxplot(extent='min-max').encode(
    x=alt.X('param_module__fc_node_num1:O'),#title="kernel size 1"),
    y='mean_test_f1_macro:Q',
    #color=alt.Color('param_lr:N',scale=alt.Scale(scheme='tableau10')),
    column='opt_name:N',
    row='param_lr:N',
).interactive(
).properties(
    height=100,
    width=100
)
# Out:
# alt.Chart(...)

# %%
top_df = sm_res_df.sort_values('rank_test_f1_macro').head(100)

alt.Chart(top_df).mark_point(size=100).encode(
    x=alt.X('param_module__num_filters1:O'),#title="kernel size 1"),
    y='mean_test_f1_macro:Q',
    color=alt.Color('rank_test_f1_macro:Q',scale=alt.Scale(scheme='viridis')),
    column='param_module__kernel_size1:N',
    shape='opt_name:N',
    row='param_lr:N',
).interactive(
).properties(
    height=100,
    width=100
)
# Out:
# alt.Chart(...)

# %%
# can I reload the model here and make predictions?

# %%
# couldn't load from pickle because waffle didn't have a GPU... maybe do this later if it matters
